# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import mosek
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-8e3eb3b04803> in <module>()
# ----> 1 import mosek
#
# ImportError: No module named mosek

# %%
import cvxpy as cvx

# Create two scalar optimization variables.
x = Variable(400)
y = np.random.randn(400)

# Create two constraints.
constraints = [x[4]>= 4,
               x[5]>=5,
               cvx.norm1(x) <= 100]
obj = Minimize(cvx.norm2(x-y))


# Form and solve problem.
# %time prob = Problem(obj, constraints)
prob.solve()  # Returns the optimal value.
print "status:", prob.status
print "optimal value", prob.value
# Out:
# CPU times: user 84 µs, sys: 1 µs, total: 85 µs
# Wall time: 98 µs
# status: optimal
# optimal value 13.7403583967

# %%
figure(figsize=(20,10))
plot(x.value.A1)
plot(y)
